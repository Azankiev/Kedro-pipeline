# %%
import pandas as pd
import boto3

from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 4
#       1 import pandas as pd
#       2 import boto3
# ----> 4 from matplotlib import pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# %env AWS_ACCESS_KEY_ID=ASIAV65BRBK4G3RANL5E
# %env AWS_SECRET_ACCESS_KEY=8b8N6Wx9OtxlBEOTlBNb88CX1gKy9Qm/PuKbvI4F
# %env AWS_SESSION_TOKEN=...
# Out:
# env: AWS_ACCESS_KEY_ID=ASIAV65BRBK4G3RANL5E
# env: AWS_SECRET_ACCESS_KEY=8b8N6Wx9OtxlBEOTlBNb88CX1gKy9Qm/PuKbvI4F
# env: AWS_SESSION_TOKEN=...

# %%
# !aws s3 ls cur-billing-pocs/CUR/CUR/CUR/year=2023/month=4/
# Out:
# 2023-05-03 11:39:17      66627 CUR-00001.snappy.parquet
# 2023-05-03 11:39:17   27757658 CUR-00002.snappy.parquet

# %%
s3 = boto3.client('s3')
s3.download_file('cur-billing-pocs', 'CUR/CUR/CUR/year=2023/month=4/CUR-00002.snappy.parquet', 'cur_00001.parquet')
s3.download_file('cur-billing-pocs', 'CUR/CUR/CUR/year=2023/month=4/CUR-00002.snappy.parquet', 'cur_00002.parquet')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 s3 = boto3.client('s3')
#       2 s3.download_file('cur-billing-pocs', 'CUR/CUR/CUR/year=2023/month=4/CUR-00002.snappy.parquet', 'cur_00001.parquet')
#       3 s3.download_file('cur-billing-pocs', 'CUR/CUR/CUR/year=2023/month=4/CUR-00002.snappy.parquet', 'cur_00002.parquet')
#
# NameError: name 'boto3' is not defined

# %%
cur_2 = pd.read_parquet('cur_00001.parquet', engine='pyarrow')
cols = list(cur_2.columns)
print(f'Shape: {cur_2.shape}')
cur_2.head()
# Out:
# Shape: (970210, 218)
#                                identity_line_item_id  \
# 0  hkfdaickefiyhcisqmcrveadihyywe3gpjeuqblgh6euhs...
# 1  n2hi7l2oehxyii3t5oieizemmrevrdumsjh4lgq77b4osx...
# 2  uvx5q2n7njsk5gbobcnkcrt4rkeehvjbujl6eiay4zsjl5...
# 3  kyy35fghntwhu66pyhexiq543hvjjkezzrkjcmiam3jm6j...
# 4  evytcnwhf3dn3ngq2awt3hmk5av2spvxbfhfxeir7luilk...
#
#                       identity_time_interval bill_invoice_id  \
# 0  2023-04-01T00:00:00Z/2023-05-01T00:00:00Z      1332346585
# 1  2023-04-01T00:00:00Z/2023-05-01T00:00:00Z      1332346585
# 2  2023-04-01T00:00:00Z/2023-05-01T00:00:00Z      1332346585
# 3  2023-04-01T00:00:00Z/2023-05-01T00:00:00Z      1332346585
# 4  2023-04-01T00:00:00Z/2023-04-18T13:19:01Z      1332346585
#
#               bill_invoicing_entity bill_billing_entity bill_bill_type  \
# 0  Amazon AWS Serviços Brasil Ltda.                 AWS    Anniversary
# 1  Amazon AWS Serviços Brasil Ltda.                 AWS    Anniversary
# ...

# %%
cur_1 = pd.read_parquet('cur_00001.parquet', engine='pyarrow')
cols = list(cur_1.columns)
print(f'Shape: {cur_1.shape}')
cur_1.head()
# Out:
# Shape: (970210, 218)
#                                identity_line_item_id  \
# 0  hkfdaickefiyhcisqmcrveadihyywe3gpjeuqblgh6euhs...
# 1  n2hi7l2oehxyii3t5oieizemmrevrdumsjh4lgq77b4osx...
# 2  uvx5q2n7njsk5gbobcnkcrt4rkeehvjbujl6eiay4zsjl5...
# 3  kyy35fghntwhu66pyhexiq543hvjjkezzrkjcmiam3jm6j...
# 4  evytcnwhf3dn3ngq2awt3hmk5av2spvxbfhfxeir7luilk...
#
#                       identity_time_interval bill_invoice_id  \
# 0  2023-04-01T00:00:00Z/2023-05-01T00:00:00Z      1332346585
# 1  2023-04-01T00:00:00Z/2023-05-01T00:00:00Z      1332346585
# 2  2023-04-01T00:00:00Z/2023-05-01T00:00:00Z      1332346585
# 3  2023-04-01T00:00:00Z/2023-05-01T00:00:00Z      1332346585
# 4  2023-04-01T00:00:00Z/2023-04-18T13:19:01Z      1332346585
#
#               bill_invoicing_entity bill_billing_entity bill_bill_type  \
# 0  Amazon AWS Serviços Brasil Ltda.                 AWS    Anniversary
# 1  Amazon AWS Serviços Brasil Ltda.                 AWS    Anniversary
# ...
