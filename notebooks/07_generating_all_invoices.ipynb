# %%
import pandas as pd

pd.set_option('display.max_columns', 30)
pd.set_option('display.max_rows', 100)

# %%
catalog.list()
# Out:
# ['2023_05_infra2_agg_invoices',
#  's3_pocs_cur_dataset',
#  's3_intelbras_cur_dataset',
#  's3_infra2_cur_dataset',
#  'accounts_per_organization',
#  'pocs_cur_dataset',
#  'intelbras_cur_dataset',
#  'infra2_cur_dataset',
#  'processed_accounts_per_organization',
#  'infra2_cur_dataset_agg',
#  'infra2_cur_dataset_agg_enriched',
#  'pocs_cur_dataset_merged',
#  'intelbras_cur_dataset_merged',
#  'infra2_agg_invoices',
#  'infra2_cur_dataset_merged',
#  'parameters',
#  'params:data_prep_raw_params',
#  'params:data_prep_raw_params.kept_columns',
#  'params:data_engineering_params',
#  'params:data_analytics_params',
#  'params:data_analytics_params.unique_invoice_line_columns',
#  'params:data_analytics_params.cost_column',
#  'params:data_analytics_params.item_type_column',
#  'params:data_analytics_params.default_item_type_values',
#  'params:data_analytics_params.discount_spp_column',
#  'params:data_analytics_params.discount_total_column']

# %%
infra2_invoices = catalog.load('infra2_agg_invoices')
infra2_invoices['2023_05_CUR.csv']
# Out:
# [07/24/23 14:07:00] INFO     Loading data from 'infra2_agg_invoices' (PartitionedDataSet)...    ]8;id=188569;file:///home/ubuntu/datarain-aws-cur-finops/venv_kedro/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=860102;file:///home/ubuntu/datarain-aws-cur-finops/venv_kedro/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
# <bound method AbstractVersionedDataSet.load of <kedro_datasets.pandas.csv_dataset.CSVDataSet object at 0x7fb4a9416e90>>

# %%
infra2_202305 = infra2_invoices['2023_05_CUR.csv']()
infra2_202305
# Out:
#      bill_invoice_id bill_payer_account_id bill_billing_period_start_date  \
# 0         1343605689          981064078967                     2023-05-01
# 1         1343605689          981064078967                     2023-05-01
# 2         1343605689          981064078967                     2023-05-01
# 3         1343605689          981064078967                     2023-05-01
# 4         1343605689          981064078967                     2023-05-01
# ..               ...                   ...                            ...
# 386       1349042489          981064078967                     2023-05-01
# 387       1349042489          981064078967                     2023-05-01
# 388       1349042489          981064078967                     2023-05-01
# 389       1366015353          981064078967                     2023-05-01
# 390       1366015353          981064078967                     2023-05-01
#
#     bill_billing_period_end_date line_item_usage_account_id  \
# ...

# %%
infra2_202305.groupby(by=['bill_invoice_id', 'bill_billing_period_start_date',  'bill_billing_period_end_date', 'usage_account_name']).agg({'charges': 'sum', 'discount_spp': 'sum', 'credits': 'sum', 'tax': 'sum', 'total': 'sum'})
# Out:
#                                                                                                                          charges  \
# bill_invoice_id bill_billing_period_start_date bill_billing_period_end_date usage_account_name
# 1343605689      2023-05-01                     2023-06-01                   Bipp Care                                 792.436957
#                                                                             Ceramica Atlas                              4.075594
#                                                                             Cordvida                                 1220.446747
#                                                                             Cotrijal                                  755.696210
#                                                                             EOS                                      1172.170658
# ...

# %%
# !pip install great_expectations
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 48.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.6/813.6 kB 57.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 84.6 MB/s eta 0:00:00:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 kB 17.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 kB 18.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.3/36.3 MB 37.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 14.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 9.0 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2
# [notice] To update, run: pip install --upgrade pip

# %%
import re


def _group_month_year_extractor(fpath: str):
    
    groups = GROUP_MONTH_YEAR_REGEX.match(fpath).groups()
    year_month = f'{groups[0]}_CUR.csv'

    return year_month

# %%
for fpath in rnp_cur.keys():
    print(_group_month_year_extractor(fpath))
# Out:
# 2021_04_CUR.csv
# 2021_04_CUR.csv
# 2021_04_CUR.csv
# 2021_05_CUR.csv
# 2021_05_CUR.csv
# 2021_05_CUR.csv
# 2021_05_CUR.csv
# 2021_06_CUR.csv
# 2021_06_CUR.csv
# 2021_06_CUR.csv
# 2021_07_CUR.csv
# 2021_07_CUR.csv
# 2021_07_CUR.csv
# 2021_08_CUR.csv
# 2021_08_CUR.csv
# 2021_08_CUR.csv
# 2021_09_CUR.csv
# 2021_09_CUR.csv
# 2021_09_CUR.csv
# 2021_10_CUR.csv
# 2021_10_CUR.csv
# 2021_11_CUR.csv
# 2021_11_CUR.csv
# 2021_11_CUR.csv
# 2021_12_CUR.csv
# 2021_12_CUR.csv
# 2021_12_CUR.csv
# 2022_01_CUR.csv
# 2022_01_CUR.csv
# 2022_01_CUR.csv
# 2022_02_CUR.csv
# 2022_02_CUR.csv
# 2022_02_CUR.csv
# 2022_02_CUR.csv
# 2022_03_CUR.csv
# 2022_03_CUR.csv
# 2022_03_CUR.csv
# 2022_04_CUR.csv
# 2022_04_CUR.csv
# 2022_04_CUR.csv
# 2022_04_CUR.csv
# 2022_04_CUR.csv
# 2022_05_CUR.csv
# 2022_05_CUR.csv
# 2022_05_CUR.csv
# 2022_06_CUR.csv
# 2022_06_CUR.csv
# 2022_06_CUR.csv
# 2022_07_CUR.csv
# 2022_07_CUR.csv
# 2022_07_CUR.csv
# 2022_07_CUR.csv
# 2022_08_CUR.csv
# 2022_08_CUR.csv
# 2022_08_CUR.csv
# ...

# %%
example = '2021_04_map-migrated-report-00001.csv'
groups = regex.match(example).groups()

groups[0] + groups[2]
# Out:
# '2021_04_00001.csv'

# %%
rnp_cur = catalog.load('rnp_cur_dataset')
rnp_cur
# Out:
# [07/31/23 18:59:24] INFO     Loading data from 'rnp_cur_dataset' (PartitionedDataSet)...        ]8;id=316987;file:///home/ubuntu/datarain-aws-cur-finops/venv_kedro/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=418234;file:///home/ubuntu/datarain-aws-cur-finops/venv_kedro/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
# {'2021_04_map-migrated-report-00001.csv': <bound method AbstractVersionedDataSet.load of <kedro_datasets.pandas.csv_dataset.CSVDataSet object at 0x7f15836447c0>>,
#  '2021_04_map-migrated-report-00002.csv': <bound method AbstractVersionedDataSet.load of <kedro_datasets.pandas.csv_dataset.CSVDataSet object at 0x7f1583647cd0>>,
#  '2021_04_map-migrated-report-00003.csv': <bound method AbstractVersionedDataSet.load of <kedro_datasets.pandas.csv_dataset.CSVDataSet object at 0x7f1583645a80>>,
# ...
